# %% [markdown]
# Homework **#2** for course **Machine Learning for Data Analysis**
# ## Running a Random Forest

# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
import sklearn.metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Import and estimate data

# %%
data = pd.read_csv("addhealth.csv")
data_clean = data.dropna()
data_clean.dtypes
data_clean.describe()
# Out:
#            BIO_SEX     HISPANIC        WHITE        BLACK    NAMERICAN  \
# count  4575.000000  4575.000000  4575.000000  4575.000000  4575.000000
# mean      1.521093     0.111038     0.683279     0.236066     0.036284
# std       0.499609     0.314214     0.465249     0.424709     0.187017
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000     0.000000     0.000000
# 50%       2.000000     0.000000     1.000000     0.000000     0.000000
# 75%       2.000000     0.000000     1.000000     0.000000     0.000000
# max       2.000000     1.000000     1.000000     1.000000     1.000000
#
#              ASIAN          age        TREG1      ALCEVR1    ALCPROBS1  \
# count  4575.000000  4575.000000  4575.000000  4575.000000  4575.000000
# mean      0.040437    16.493052     0.176393     0.527432     0.369180
# std       0.197004     1.552174     0.381196     0.499302     0.894947
# ...

# %% [markdown]
# ### Data preproccessing

# %%
features = list(data_clean.columns.values)
X = data_clean[features]
X.drop('TREG1', axis=1, inplace=True)
y = data_clean[['TREG1']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ###  Fitting random forest classifier

# %%
RF_clf = RandomForestClassifier(n_estimators=25, random_state=777)
RF_clf = RF_clf.fit(X_train, y_train)
predictions = RF_clf.predict(X_test)
# Out:
# /Users/elisavetakarpova/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %% [markdown]
# ### Validate results

# %%
print("Confusion matrix:\n", sklearn.metrics.confusion_matrix(y_test,predictions))
print("Accuracy: ",sklearn.metrics.accuracy_score(y_test, predictions))
# Out:
# Confusion matrix:
#  [[1072   65]
#  [ 135  101]]
# Accuracy:  0.854333576111

# %% [markdown]
# ### Estimating importance of features

# %%
important_features = pd.Series(data=RF_clf.feature_importances_,index=X.columns)
important_features.sort_values(ascending=False,inplace=True)

print(important_features)
# Out:
# marever1     0.103942
# age          0.082291
# GPA1         0.078134
# DEVIANT1     0.073211
# FAMCONCT     0.072930
# SCHCONN1     0.071027
# ESTEEM1      0.067329
# DEP1         0.066870
# ALCPROBS1    0.061207
# PARACTV      0.057561
# VIOL1        0.048049
# ALCEVR1      0.044285
# PARPRES      0.042615
# WHITE        0.022735
# cigavail     0.017613
# cocever1     0.015261
# BLACK        0.014281
# BIO_SEX      0.012272
# PASSIST      0.010729
# HISPANIC     0.009750
# inhever1     0.009304
# EXPEL1       0.009277
# NAMERICAN    0.005256
# ASIAN        0.004069
# dtype: float64
